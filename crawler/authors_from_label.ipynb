# %%
import os
import json
from dataclasses import dataclass
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By

from bs4 import BeautifulSoup

Computer_Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_vision"
computational_materials_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_materials_science"
computational_nano_mechanics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_nano_mechanics"
molecular_dynamics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:molecular_dynamics"
density_functional_theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:density_functional_theory"
li_ion_batteries = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:li_ion_batteries"
Machine_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_learning"
AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai"
machine_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_learning"
computer_vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_vision"
robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robotics"
image_compression = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_compression"
Deep_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:deep_learning"
Autonomous_Driving = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_driving"
Neural_Network_Architectures = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_network_architectures"
Efficient_Deep_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:efficient_deep_learning"
Biomaterials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomaterials"
Surface_modification_of_metals = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:surface_modification_of_metals"
Cardiovascular_disease = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cardiovascular_disease"
Biometrics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biometrics"
Computer_vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_vision"
Pattern_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_recognition"
Machine_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_learning"
Image_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_processing"
Artificial_Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:artificial_intelligence"
Neuroscience = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neuroscience"
artificial_intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:artificial_intelligence"
computer_graphics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_graphics"
autonomous_cars = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_cars"
cultural_heritage = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cultural_heritage"
deep_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:deep_learning"
image_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_processing"
medical_imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_imaging"
and_graphics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:and_graphics"
natural_language_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:natural_language_processing"
Image_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_processing"
Pattern_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_recognition"
Multimedia = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia"
Robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robotics"
Speech_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speech_recognition"
Partial_Differential_Equations = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:partial_differential_equations"
Medical_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_imaging"
geometric_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometric_computing"
computational_photography = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_photography"
vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:vision"
Integrated_circuits = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:integrated_circuits"
Analog_and_Mixed_Signal = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:analog_and_mixed_signal"
RF_circuits = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:rf_circuits"
Low_power = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:low_power"
Wireless_Sensor_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:wireless_sensor_networks"
Image_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_analysis"
Biomedical_Applications = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_applications"
Particle_Physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:particle_physics"
graphics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:graphics"
prediction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:prediction"
Computational_Models_of_Mind_and_Brain = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_models_of_mind_and_brain"
Natural_Language_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:natural_language_processing"
psychometrics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:psychometrics"
performance_appraisal = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:performance_appraisal"
personnel_assessment = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:personnel_assessment"
statistics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistics"
Deep_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:deep_learning"
reinforcement_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:reinforcement_learning"
Information_Retrieval = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:information_retrieval"
Type_Theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:type_theory"
Scene_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:scene_understanding"
biometrics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biometrics"
Biomedical_Data_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_data_science"
Fuel_Cell_Electrocatalysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fuel_cell_electrocatalysis"
Supercapacitor = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:supercapacitor"
CO2_reduction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:co2_reduction"
Batteries = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:batteries"
Advanced_Materials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:advanced_materials"
metric_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:metric_learning"
pattern_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_recognition"
affective_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:affective_computing"
Document_Image_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:document_image_analysis"
AI_for_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_for_science"
Reliable_and_Trustworthy_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:reliable_and_trustworthy_ai"
Digital_health = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_health"
Computational_Advertising = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_advertising"
Computer_Graphics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_graphics"
Virtual_Humans = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:virtual_humans"
Optical_Flow = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optical_flow"
cooling_and_drying = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cooling_and_drying"
food_quality_and_safety = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:food_quality_and_safety"
bioprocess_simulation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioprocess_simulation"
hyperspectral_imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hyperspectral_imaging"
Protein_structure_prediction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:protein_structure_prediction"
Speech_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speech_recognition"
Augmented_Reality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:augmented_reality"
Biomedical_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_imaging"
optimization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optimization"
forensic_imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:forensic_imaging"
Cognitive_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cognitive_science"
Medical_Image_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_image_analysis"
Computer_Aided_Design = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_aided_design"
Signal_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:signal_processing"
Speech = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speech"
Self_Supervised_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:self_supervised_learning"
object_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:object_recognition"
continual_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:continual_learning"
Autonomous_driving = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_driving"
Neural_Coding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_coding"
plant_biotechnology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_biotechnology"
transgenic_plants = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:transgenic_plants"
plant_pathology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_pathology"
plant_nematodes = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_nematodes"
plant_viruses = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_viruses"
computational_gastronomy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_gastronomy"
Computational_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_imaging"
Computational_Photography = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_photography"
Data_Mining = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_mining"
Optimization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optimization"
Neural_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_networks"
Unsupervised_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:unsupervised_learning"
Machine_Translation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_translation"
Machine_Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_vision"
machine_perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_perception"
machine_intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_intelligence"
Algebra = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:algebra"
Machine_Perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_perception"
algebraic_geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:algebraic_geometry"
multimedia = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia"
Medical_Image_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_image_computing"
Image_Guided_Interventions = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_guided_interventions"
Multimedia_Information_Retrieval = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_information_retrieval"
Bioimage_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioimage_analysis"
Reinforcement_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:reinforcement_learning"
Biomedical_Image_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_image_analysis"
Computational_Biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_biology"
Transcription_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:transcription_imaging"
Software_Development = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:software_development"
C_elegans = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:c_elegans"
Search = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:search"
Social_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:social_computing"
Artifical_Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:artifical_intelligence"
SLAM = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:slam"
Generative_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:generative_ai"
Vision_and_Language = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:vision_and_language"
Non_invasive_assessment_of_plant_physiology_remote_sensing_and_plant_phenotying = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:non_invasive_assessment_of_plant_physiology_remote_sensing_and_plant_phenotying"
Large_Multimodal_Model = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:large_multimodal_model"
Large_Language_Model = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:large_language_model"
Domain_Adaptation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:domain_adaptation"
Human_Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_vision"
medical_image_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_image_analysis"
medical_image_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_image_computing"
scene_understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:scene_understanding"
Biomaterials_Nanomedicine = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomaterials_%26_nanomedicine"
Image_Based_Rendering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_based_rendering"
face_and_gesture_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:face_and_gesture_recognition"
Computer_Architecture = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_architecture"
Healthcare = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:healthcare"
Computer_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_science"
neural_networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_networks"
data_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_science"
Artificial_intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:artificial_intelligence"
machine_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_learning"
Visual_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_computing"
Social_Network_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:social_network_analysis"
Programming_Languages = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:programming_languages"
digital_epidemiology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_epidemiology"
information_retrieval = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:information_retrieval"
digital_watermarking = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_watermarking"
cardiology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cardiology"
heart_failure = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:heart_failure"
stem_cells = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:stem_cells"
translational = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:translational"
Shape_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:shape_analysis"
Geometric_Modeling = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometric_modeling"
Geometry_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometry_processing"
Visual_Attention = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_attention"
Saliency = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:saliency"
Action_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:action_recognition"
Object_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:object_recognition"
multimedia_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_analysis"
Video_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_analysis"
Data_Analytics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_analytics"
Signal_and_Image_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:signal_and_image_processing"
Media_Security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:media_security"
Communications = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:communications"
Information_Theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:information_theory"
Networking = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:networking"
Human_Computer_Interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_computer_interaction"
Mobile_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mobile_computing"
plant_metabolism = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_metabolism"
plant_defense_mechanism = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_defense_mechanism"
plant_insect_interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_insect_interaction"
shikimate_pathway = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:shikimate_pathway"
aromatic_amino_acids = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:aromatic_amino_acids"
Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:vision"
Representation_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:representation_learning"
network_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:network_science"
Medical_image_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_image_analysis"
biomedical_image_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_image_analysis"
Iris_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:iris_recognition"
image_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_analysis"
shape_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:shape_analysis"
Text_Mining = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:text_mining"
Neural_Computation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_computation"
Indexing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:indexing"
data_mining = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_mining"
face_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:face_recognition"
Medicine = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medicine"
HCI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hci"
Quantitative_Genetics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:quantitative_genetics"
Statistical_Genetics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistical_genetics"
Human_Genetics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_genetics"
Formal_Methods = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:formal_methods"
control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:control"
field_robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:field_robotics"
sensor_networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:sensor_networks"
human_computer_interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_computer_interaction"
Computational_Physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_physics"
Fluid_mechanics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fluid_mechanics"
Computational_fluid_dynamics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_fluid_dynamics"
Random_Forests = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:random_forests"
Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:learning"
Cognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cognition"
Autonomy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomy"
OCR = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ocr"
Mixed_Reality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mixed_reality"
Neural_networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_networks"
Computer_graphics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_graphics"
human_vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_vision"
consciousness = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:consciousness"
experimental_psychology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:experimental_psychology"
differential_geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:differential_geometry"
Algorithms = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:algorithms"
autonomous_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_systems"
digital_media = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_media"
AI__Machine_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_%26_machine_learning"
Virtual_Augmented_Reality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:virtual_augmented_reality"
Compression = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:compression"
Visualization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visualization"
AutoML = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:automl"
signal_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:signal_processing"
control_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:control_systems"
Good_Shit = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:good_shit"
Systems_and_Control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:systems_and_control"
Applied_Mathematics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:applied_mathematics"
probabilistic_inference = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:probabilistic_inference"
bayesian_nonparametrics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bayesian_nonparametrics"
Multimedia_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_analysis"
recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:recognition"
augmented_reality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:augmented_reality"
geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometry"
Face_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:face_recognition"
driver_assistance = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:driver_assistance"
public_safety = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:public_safety"
surveillance = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:surveillance"
security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:security"
Multimedia_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_analysis"
Data_mining = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_mining"
Information_retrieval = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:information_retrieval"
Manifold_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:manifold_learning"
Dictionary_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:dictionary_learning"
human_computer_interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_computer_interaction"
Video_Information_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_information_analysis"
information_theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:information_theory"
iris_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:iris_recognition"
Multimodal_Interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimodal_interaction"
Astrophysics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:astrophysics"
Digital_Image_Correlation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_image_correlation"
Stereo_Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:stereo_vision"
Fracture_Mechanics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fracture_mechanics"
Biomechanics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomechanics"
metric_geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:metric_geometry"
Structural_Materials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:structural_materials"
Control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:control"
Multimodal_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimodal_learning"
Object_Re_identification = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:object_re_identification"
Dataset_centered_Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:dataset_centered_vision"
NLP = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nlp"
Computing_with_Words = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computing_with_words"
Control_Theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:control_theory"
Tracking = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:tracking"
Neurosurgery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neurosurgery"
parallel_and_distributed = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:parallel_and_distributed"
biological_image_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biological_image_analysis"
Language_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:language_understanding"
Multimodal_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimodal_ai"
numerical_optimization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:numerical_optimization"
Image_Recognition_and_Generation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_recognition_and_generation"
Quantum_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:quantum_computing"
Statistical_Machine_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistical_machine_learning"
Visual_Question_Answering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_question_answering"
Molucular_biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:molucular_biology"
multimedia_communications = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_communications"
Transfer_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:transfer_learning"
Computational_Structural_Biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_structural_biology"
Structural__Bioinformatics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:structural_bioinformatics"
Geometric_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometric_computing"
Spatial_Pattern_Discovery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:spatial_pattern_discovery"
image_understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_understanding"
color = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:color"
Pattern_Recogniton = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_recogniton"
THREE_D_Perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:3d_perception"
Genomics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:genomics"
Bioinformatics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioinformatics"
Oncology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:oncology"
Data_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_science"
Computed_Tomography = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computed_tomography"
Cardiovascular_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cardiovascular_imaging"
Convex_optimization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:convex_optimization"
Variational_methods = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:variational_methods"
visual_effects = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_effects"
virtual_reality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:virtual_reality"
Photogrammetry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:photogrammetry"
Remote_Sensing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:remote_sensing"
biomedical_informatics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_informatics"
art = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:art"
Robot_Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_vision"
Neuroimaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neuroimaging"
Mathematics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mathematics"
adult_stem_cells = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:adult_stem_cells"
regeneration = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:regeneration"
zebrafish = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:zebrafish"
melanocytes = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:melanocytes"
Big_Data = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:big_data"
pattern_recogntion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_recogntion"
Computational_Fabrication = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_fabrication"
Multimedia_Analysis_and_Retrieval = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_analysis_and_retrieval"
Image_and_Video_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_and_video_processing"
Video_Coding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_coding"
Design = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:design"
Automation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:automation"
and_Test_for_Integrated_Circuits = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:and_test_for_integrated_circuits"
AI_for_radiology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_for_radiology"
Scale_Space = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:scale_space"
Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:recognition"
Biomedical_Image_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_image_understanding"
applications_of_probability = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:applications_of_probability"
consumer_electronics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:consumer_electronics"
edge_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:edge_computing"
Affective_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:affective_computing"
Medical_imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_imaging"
Transportation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:transportation"
Intelligent_Transportation_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intelligent_transportation_systems"
Video_Mining = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_mining"
Human_Machine_Interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_machine_interaction"
MultiModal_Data_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimodal_data_analysis"
Computer_Aided_Design = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_aided_design"
Statistics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistics"
Probability_Theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:probability_theory"
Global_Development = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:global_development"
ICT_and_Development = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ict_and_development"
Medical_Imaging_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_imaging_analysis"
Protein_Structure_Prediction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:protein_structure_prediction"
Generative_Models = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:generative_models"
signal_transduction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:signal_transduction"
cell_biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cell_biology"
molecular_biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:molecular_biology"
protein_engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:protein_engineering"
protein_design = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:protein_design"
Geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometry"
Algebraic_Geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:algebraic_geometry"
AI_in_Healthcare = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_in_healthcare"
Graph_Neural_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:graph_neural_networks"
Eye_Movements = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:eye_movements"
Benchmarking = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:benchmarking"
Gait = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:gait"
Ear = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ear"
Soft = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:soft"
Graphical_Models = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:graphical_models"
population_genetics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:population_genetics"
bioinformatics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioinformatics"
human_genomics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_genomics"
Video_Analytics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_analytics"
Trustworthy_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:trustworthy_ai"
AGI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:agi"
Aritificial_Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:aritificial_intelligence"
digital_twin = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_twin"
multimedia_communications_security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_communications_security"
grasping = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:grasping"
robotic_surgery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robotic_surgery"
Quantitative_Finance = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:quantitative_finance"
Immunology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:immunology"
virus = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:virus"
infection = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:infection"
Mobile_robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mobile_robotics"
Perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:perception"
Reinforcement_Learning_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:reinforcement_learning_%26_ai"
Object_Detection = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:object_detection"
Object_Segmentation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:object_segmentation"
systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:systems"
Biomedical_image_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_image_analysis"
image_guided_intervention = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_guided_intervention"
Variational_Methods = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:variational_methods"
Computational_Interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_interaction"
automated_driving = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:automated_driving"
artifical_intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:artifical_intelligence"
communications = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:communications"
video_coding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_coding"
embodied_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:embodied_ai"
Systems_Engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:systems_engineering"
solid_state_physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:solid_state_physics"
valleytronics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:valleytronics"
TWO_D_materials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:2d_materials"
remote_sensing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:remote_sensing"
Image_Fusion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_fusion"
cognitive_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cognitive_science"
Psychology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:psychology"
Document_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:document_analysis"
Media_Forensics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:media_forensics"
Language_Technologies = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:language_technologies"
Numerical_Optimization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:numerical_optimization"
Distributed_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:distributed_computing"
Efficient_Algorithms = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:efficient_algorithms"
Semantic_Web = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:semantic_web"
Semantic_Provenance = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:semantic_provenance"
Digital_Geometry_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_geometry_processing"
THREE_D_Photography = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:3d_photography"
Privacy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:privacy"
Visual_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_computing"
multimedia_networking = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_networking"
attention = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:attention"
computational_neuroscience = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_neuroscience"
structure_from_motion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:structure_from_motion"
photo_collection_reconstruction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:photo_collection_reconstruction"
stereo = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:stereo"
robust_estimation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robust_estimation"
Explainable_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:explainable_ai"
Education = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:education"
circulant_matrices = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:circulant_matrices"
fourier_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fourier_analysis"
speech_language = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speech%26language"
Video_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_understanding"
pattern_recognition_machine_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_recognition_%26_machine_learning"
computational_imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_imaging"
Artificial__Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:artificial_intelligence"
Security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:security"
Autonomous_Vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_vehicles"
Continual_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:continual_learning"
Incremental_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:incremental_learning"
Color_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:color_imaging"
Structural_Dynamics_Control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:structural_dynamics_%26_control"
Earthquake_Engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:earthquake_engineering"
Cyberinfrastructure = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cyberinfrastructure"
Structural_Monitoring = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:structural_monitoring"
brain_inspired_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:brain_inspired_computing"
Virtual_Reality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:virtual_reality"
AI_Generated_Content = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_generated_content"
AI_for_Medicine = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_for_medicine"
Information_Fusion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:information_fusion"
Semantic_Perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:semantic_perception"
behavioral_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:behavioral_science"
Multimodal_interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimodal_interaction"
Accessibility = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:accessibility"
Two_dimensional_materials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:two_dimensional_materials"
Graphene = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:graphene"
Black_phosphorus = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:black_phosphorus"
Optics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optics"
Devices = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:devices"
Genetics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:genetics"
Graphics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:graphics"
Image_Reconstruction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_reconstruction"
intelligent_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intelligent_systems"
Multi_Modal_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multi_modal_learning"
Cognitive_vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cognitive_vision"
High_Energy_Physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:high_energy_physics"
Experimental_Particle_Physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:experimental_particle_physics"
Compressed_Sensing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:compressed_sensing"
THREE_D_vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:3d_vision"
Information_Hiding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:information_hiding"
Cardiovascular_Disease_Prevention = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cardiovascular_disease_prevention"
Health_Equity = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:health_equity"
Digital_Health = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_health"
Implementation_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:implementation_science"
Pattern_Recognition_and_Multimedia = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_recognition_and_multimedia"
particle_physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:particle_physics"
high_energy_phsyics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:high_energy_phsyics"
THREE_D_Reconstruction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:3_d_reconstruction"
decision_support_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:decision_support_systems"
technology_assessment = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:technology_assessment"
Intelligent_Vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intelligent_vehicles"
Pedestrian_Detection = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pedestrian_detection"
internet_of_things = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:internet_of_things"
Biomedical_engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_engineering"
Simulation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:simulation"
Mesh_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mesh_processing"
Non_Photorealistic_Rendering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:non_photorealistic_rendering"
Style_Transfer = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:style_transfer"
computational_chemistry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_chemistry"
Video_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_processing"
Data_Privacy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_privacy"
Image_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_understanding"
Visual_Surveillance = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_surveillance"
VR_AR = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:vr_ar"
Robot__Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_vision"
Digital_Document_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_document_processing"
Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computing"
Philosophy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:philosophy"
Physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:physics"
THREE_D_modeling = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:3d_modeling"
speaker_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speaker_recognition"
Network_Security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:network_security"
Social_Network = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:social_network"
transportation_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:transportation_systems"
Hypertension = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hypertension"
Pharmacology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pharmacology"
Adrenal = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:adrenal"
AI_for_Healthcare = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_for_healthcare"
Video_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_understanding"
multimodal_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimodal_learning"
wood_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:wood_science"
macromolecular_structure = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:macromolecular_structure"
Humanoid_Robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:humanoid_robots"
Micro_Air_Vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:micro_air_vehicles"
Embodied_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:embodied_ai"
Medical_Computer_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_computer_science"
computational_ophthalmology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_ophthalmology"
retina = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:retina"
Assistive_Technology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:assistive_technology"
Sensors = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:sensors"
Multimedia_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_computing"
generative_models = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:generative_models"
out_of_distribution_data = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:out_of_distribution_data"
high_energy_physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:high_energy_physics"
Social_Signal_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:social_signal_processing"
computational_behavioral_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_behavioral_science"
recurrent_neural_networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:recurrent_neural_networks"
autonomous_robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_robotics"
Open_set_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:open_set_recognition"
Statistical_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistical_learning"
Biometric_Security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biometric_security"
Physical_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:physical_ai"
Protein_and_DNA_Mechanics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:protein_and_dna_mechanics"
Applied_Math = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:applied_math"
Computational_Neuroscience = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_neuroscience"
image_and_video_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_and_video_processing"
visual_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_computing"
Generative_modeling = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:generative_modeling"
Unsupervised_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:unsupervised_learning"
Representation_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:representation_learning"
Neural_Rendering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_rendering"
document__analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:document_analysis"
Computer_Optics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_optics"
Diffractive_Nanophotonics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:diffractive_nanophotonics"
Software_Engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:software_engineering"
Humanoid_Robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:humanoid_robotics"
Robot_Perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_perception"
Cognitive_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cognitive_systems"
sensors = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:sensors"
nanotechnology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nanotechnology"
battery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:battery"
boron_nitride = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:boron_nitride"
nanotubes = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nanotubes"
nanosheets = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nanosheets"
psychiatry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:psychiatry"
Robot_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_learning"
Intelligent_User_Interfaces = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intelligent_user_interfaces"
Eye_Tracking = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:eye_tracking"
Collaborative_Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:collaborative_intelligence"
Astronomy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:astronomy"
exoplanets = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:exoplanets"
instrumentation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:instrumentation"
Computational_Anatomy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_anatomy"
Color_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:color_science"
Color_Perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:color_perception"
Emerging_infectious_diseases = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:emerging_infectious_diseases"
Haptics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:haptics"
multimedia_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_processing"
wireless_communication = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:wireless_communication"
optimizations_and_algorithms = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optimizations_and_algorithms"
Foundation_Models = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:foundation_models"
robot_perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_perception"
computer_engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_engineering"
intelligent_transportation_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intelligent_transportation_systems"
Image_Video_Compression = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_video_compression"
Image_and_Video_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_and_video_analysis"
Intelligent_Sensors = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intelligent_sensors"
FOUR_D_Modeling = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:4d_modeling"
THERR_D_Modelling = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:3d_modelling"
machine_vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_vision"
educational_technology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:educational_technology"
Neural_Symbolic_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neural_symbolic_ai"
Autonomous_Cars = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_cars"
Shape_Optimization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:shape_optimization"
Geometric_PDEs = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometric_pde%27s"
carbon_sequestration = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:carbon_sequestration"
oil = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:oil"
petroleum = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:petroleum"
fuel = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fuel"
Organic_chemistry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:organic_chemistry"
precision_medicine = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:precision_medicine"
neuroimaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neuroimaging"
wavelets = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:wavelets"
inverse_problems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:inverse_problems"
document_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:document_analysis"
Computer_Aided_Diagnosis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_aided_diagnosis"
Camera_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:camera_networks"
Hyperspectral_and_Medical_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hyperspectral_and_medical_imaging"
biological_imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biological_imaging"
skin_imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:skin_imaging"
learning_theory_and_algorithms = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:learning_theory_and_algorithms"
computational_biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_biology"
Evolutionary_Computation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:evolutionary_computation"
Feature_Selection = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:feature_selection"
NeuroEvolution = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neuroevolution"
Digital_Geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_geometry"
ADAS = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:adas"
Image_and_video_analytics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_and_video_analytics"
Multimedia_content_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_content_analysis"
Segmentation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:segmentation"
Human_Pose_Estimation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_pose_estimation"
Human_Behavior_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_behavior_analysis"
Multimodal_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimodal_learning"
Aritficial_Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:aritficial_intelligence"
lidar = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:lidar"
Affective_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:affective_computing"
image_restoration = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_restoration"
Human_Computer_Interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_computer_interaction"
Bioimage_Informatics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioimage_informatics"
nanocomposite_structures = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nanocomposite_structures"
mechanics_of_nano__micro_structures = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mechanics_of_nano_micro_structures"
smart_materials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:smart_materials"
structural_dynamics_and_stability = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:structural_dynamics_and_stability"
biomechanics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomechanics"
visualization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visualization"
document_image_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:document_image_analysis"
Body_Sensor_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:body_sensor_networks"
Pervasive_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pervasive_computing"
Machine_Learning_and_Artificial_Intelligen = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_learning_and_artificial_intelligen"
photocatalysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:photocatalysis"
photoelectrochemistry_and_adsorption = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:photoelectrochemistry_and_adsorption"
Image_Segmentation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_segmentation"
computational_statistics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_statistics"
functional_data_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:functional_data_analysis"
statistics_on_manifolds = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistics_on_manifolds"
Visual_SLAM = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_slam"
Vision_Language_Models = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:vision_language_models"
Document_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:document_understanding"
Scene_Text_Detection_and_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:scene_text_detection_and_recognition"
Computational_Ethology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_ethology"
Biometric_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biometric_recognition"
Multimedia_Retrieval = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_retrieval"
Deep_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:deep_learning"
fungi = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fungi"
biodiversity = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biodiversity"
phylogeny = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:phylogeny"
taxonomy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:taxonomy"
microbiome = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:microbiome"
Mechanism_Design = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mechanism_design"
Markov_Decision_Processes = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:markov_decision_processes"
mathematics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mathematics"
computer_science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_science"
Image_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_recognition"
Machine_learning_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_learning_ai"
diagnostics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:diagnostics"
digital_health = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_health"
Data_Mining_and_Knowledge_Discover = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_mining_and_knowledge_discover"
Multimedia_Information_Indexing_and_Retrieval = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_information_indexing_and_retrieval"
Pattern_Re = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_re"
Enterprise_Information_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:enterprise_information_systems"
Industrial_Information_Integration = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:industrial_information_integration"
Industrial_Informatics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:industrial_informatics"
IoT = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:iot"
visual_document_management = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_document_management"
Physical_models = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:physical_models"
Federated_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:federated_learning"
Soft_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:soft_computing"
Blockchain = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:blockchain"
Cholesterol = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cholesterol"
compressed_sensing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:compressed_sensing"
Probabilistic_Inference = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:probabilistic_inference"
Multimedia_Security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multimedia_security"
numerical_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:numerical_computing"
Computer_Game = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_game"
software_engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:software_engineering"
Handwritten_Character_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:handwritten_character_recognition"
Document_Analysis_and_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:document_analysis_and_recognition"
Computational_Geometry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_geometry"
interdisciplinary_computational_intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:interdisciplinary_computational_intelligence_ici"
Activity_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:activity_recognition"
Event_Detection = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:event_detection"
Biologically_inspired_Vision = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biologically_inspired_vision"
Large_scale_machine_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:large_scale_machine_learning"
Child_and_adolescent_psychiatry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:child_and_adolescent_psychiatry"
Visual_signal_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_signal_processing"
Food_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:food_computing"
Manga = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:manga"
social_networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:social_networks"
Random_Fields = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:random_fields"
cancer = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cancer"
genomics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:genomics"
genetics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:genetics"
systems_biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:systems_biology"
drug_discovery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:drug_discovery"
Biomimetic_Navigation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomimetic_navigation"
applied_cryptography = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:applied_cryptography"
Disaster_management = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:disaster_management"
Environmental_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:environmental_science"
Urban_Planning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:urban_planning"
Housing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:housing"
plant_phenotyping = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:plant_phenotyping"
infrared_thermography = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:infrared_thermography"
fundus_image = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fundus_image"
Digital_Signal_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:digital_signal_processing"
Machine_and_Deep_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_and_deep_learning"
Biomedical_Signal_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_signal_processing"
Fibrotic_lung_disease = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fibrotic_lung_disease"
Idiopathic_Pulmonary_Fibrosis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:idiopathic_pulmonary_fibrosis"
Hypergraph_Computation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hypergraph_computation"
biomedical_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_computing"
action_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:action_recognition"
video_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_processing"
perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:perception"
multiagent_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multiagent_systems"
service_oriented_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:service_oriented_computing"
ontologies = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ontologies"
distributed_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:distributed_computing"
recommender_system = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:recommender_system"
shape = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:shape"
Surveillance = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:surveillance"
Eye_Gaze_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:eye_gaze_analysis"
Computer_Audition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_audition"
Gene_Expression = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:gene_expression"
Platelets = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:platelets"
Neuromorphic_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neuromorphic_computing"
Video_Search = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_search"
Video_Archives = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:video_archives"
Computational_Cognitive_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_cognitive_science"
Self_supervised_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:self_supervised_learning"
HPC = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hpc"
Natural_Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:natural_intelligence"
Speech_Precessing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speech_precessing"
Natural_Language_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:natural_language_understanding"
Random_Field_Models = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:random_field_models"
Legged_Robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:legged_robots"
Autonomous_Airships = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_airships"
Audio_Processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:audio_processing"
Molecular_biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:molecular_biology"
Proteomics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:proteomics"
Sustainability_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:sustainability_science"
Controls = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:controls"
Exscientia = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:exscientia"
AI_and_Machine_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_and_machine_learning"
Conversational_AI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:conversational_ai"
Web_search = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:web_search"
Performance_Evaluation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:performance_evaluation"
Estimation_and_Inference = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:estimation_and_inference"
Optimization_and_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optimization_and_learning"
Facial_Analysis_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:facial_analysis_recognition"
AI_for_Climate = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ai_for_climate"
mHealth = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mhealth"
Bio_Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bio_imaging"
Multi_modal_Perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multi_modal_perception"
Mobile_Visual_Computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mobile_visual_computing"
body_sensor_networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:body_sensor_networks"
hci = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hci"
Face_and_gesture_recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:face_and_gesture_recognition"
biological_shape = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biological_shape"
Image_Enhancement = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:image_enhancement"
AR_MR_VR = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:ar_mr_vr"
and_machine_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:and_machine_learning"
speech = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speech"
data_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_processing"
Institute_of_Insect_Sciences = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:institute_of_insect_sciences"
human_computer_interface = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_computer_interface"
Visual_perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_perception"
Reality_research = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:reality_research"
THREE_D_structure_recovery_from_images = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:3d_structure_recovery_from_images"
Augmented_and_Mixed_Reality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:augmented_and_mixed_reality"
Scene_Labeling = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:scene_labeling"
Real_Time_Algorithms = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:real_time_algorithms"
Sensor_Fusion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:sensor_fusion"
Wireless_Communication = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:wireless_communication"
IoT_Cyber_Physical_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:iot_cyber_physical_systems"
Connected_and_autonomous_vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:connected_and_autonomous_vehicles"
Electric_vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:electric_vehicles"
Cancer_Biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cancer_biology"
clinical_study = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:clinical_study"
eye_diseases = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:eye_diseases"
breast_cancer = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:breast_cancer"
Computational_Intelligence = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computational_intelligence"
drug_delivery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:drug_delivery"
controlled_release = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:controlled_release"
biomaterials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomaterials"
multifunctional_nanoparticles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multifunctional_nanoparticles"
Unmanned_Aerial_Vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:unmanned_aerial_vehicles"
Robot_Operating_System = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_operating_system"
stillbirth = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:stillbirth"
neonatal_mortality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neonatal_mortality"
child_mortality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:child_mortality"
adolescent_mortality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:adolescent_mortality"
causes_of_deaths = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:causes_of_deaths"
Optical_metrology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optical_metrology"
parallel_computing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:parallel_computing"
experimental_mechanics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:experimental_mechanics"
Structural_Biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:structural_biology"
Biophysics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biophysics"
Electrophysiology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:electrophysiology"
X_Ray_Diffraction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:x_ray_diffraction"
Nuclear_Magnetic_Resonance = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nuclear_magnetic_resonance"
visual_perception = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_perception"
geoinformatics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geoinformatics"
pattern_analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pattern_analysis"
Statistical_Pattern_Recognition = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistical_pattern_recognition"
Visual_Localization = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:visual_localization"
Applied_Machine_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:applied_machine_learning"
optimization_methods = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optimization_methods"
Knowledge_Graphs = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:knowledge_graphs"
Modeling_of_Human_and_Social_Behavior = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:modeling_of_human_and_social_behavior"
Machine_Deep_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_deep_learning"
Lung_Cancer = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:lung_cancer"
Satellite_Internet = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:satellite_internet"
electrical_engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:electrical_engineering"
haptics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:haptics"
AIGC = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:aigc"
Biology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biology"
Remote_sensing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:remote_sensing"
Quality = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:quality"
filtering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:filtering"
speech_processing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:speech_processing"
Imaging = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:imaging"
Wavelet_Analysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:wavelet_analysis"
hybrid_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hybrid_systems"
cyber_security = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cyber_security"
embedded_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:embedded_systems"
Gene_Therapy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:gene_therapy"
Liver_Surgery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:liver_surgery"
Pancreatic_Surgery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:pancreatic_surgery"
General_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:general_science"
Dynamical_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:dynamical_systems"
Complex_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:complex_systems"
Wireless_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:wireless_networks"
geometric_modeling = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:geometric_modeling"
motion_planning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:motion_planning"
Medical_Robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_robotics"
Computer_Integrated_Surgery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_integrated_surgery"
Computer_Assisted_Surgery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_assisted_surgery"
Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:systems"
scientific_discovery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:scientific_discovery"
Motor_Neuroscience = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:motor_neuroscience"
Human_Robot_Interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_robot_interaction"
Human_Motion_Understanding = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:human_motion_understanding"
Microrobotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:microrobotics"
Soft_Matter = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:soft_matter"
Materials_Science = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:materials_science"
mechatronics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mechatronics"
Data_Fusion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:data_fusion"
Estimation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:estimation"
Multiagent_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multiagent_systems"
Additive_Manufacturing = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:additive_manufacturing"
Mechanical_Engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mechanical_engineering"
Planning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:planning"
Multirobot_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multirobot_systems"
Socially_Assistive_Robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:socially_assistive_robotics"
Assistive_Technologies = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:assistive_technologies"
Control_theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:control_theory"
automatic_control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:automatic_control"
cyber_physical_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cyber_physical_systems"
Nanorobotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nanorobotics"
statistical_physics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:statistical_physics"
Heterogeneous_catalysis = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:heterogeneous_catalysis"
Nanomaterials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nanomaterials"
Drug_delivery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:drug_delivery"
Electron_microscopy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:electron_microscopy"
Tissue_Engineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:tissue_engineering"
control_theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:control_theory"
system_theory = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:system_theory"
Computer_Animation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:computer_animation"
Parallel_Robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:parallel_robots"
Robotic_Hands = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robotic_hands"
Physical_Human_Robot_Interaction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:physical_human_robot_interaction"
economics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:economics"
global_trends = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:global_trends"
future_of_work = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:future_of_work"
sensor_fusion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:sensor_fusion"
Telerobotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:telerobotics"
Physical_Human_Robot_Interactions = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:physical_human_robot_interactions"
Robot_Dynamics_and_Controls = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_dynamics_and_controls"
Robot_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_networks"
Motion_Planning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:motion_planning"
Automatic_Control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:automatic_control"
Autonomous_vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_vehicles"
Robotic_Networks = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robotic_networks"
Intelligent_Transportation_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intelligent_transportation_systems"
Marine_Robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:marine_robotics"
prostate_cancer = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:prostate_cancer"
bladder_cancer = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bladder_cancer"
urogenital_reconstruction = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:urogenital_reconstruction"
Robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robots"
Collaborative_Filtering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:collaborative_filtering"
Exoskeletons = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:exoskeletons"
Teleoperation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:teleoperation"
Model_Predictive_Control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:model_predictive_control"
Airborne_Wind_Energy = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:airborne_wind_energy"
Decision_making_uncertainty = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:decision_making_uncertainty"
Stroke = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:stroke"
Intracranial_aneurysms = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:intracranial_aneurysms"
AVMs = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:avms"
Hemodynamics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:hemodynamics"
Self_driving_Vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:self_driving_vehicles"
Sustainable_materials = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:sustainable_materials"
bioinspiration = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioinspiration"
biomedicine = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedicine"
fuzzy_control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:fuzzy_control"
unmanned_aerial_vehicles = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:unmanned_aerial_vehicles"
brain_machine_interface = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:brain_machine_interface"
nonlinear_control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nonlinear_control"
bio_inspired_design = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bio_inspired_design"
photogrammetry = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:photogrammetry"
autonomous_driving = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_driving"
Deep_Reinforcement_Learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:deep_reinforcement_learning"
MRI = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:mri"
neurosurgery = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neurosurgery"
Humanoid = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:humanoid"
Bio_Medical = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bio_medical"
Neuro = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neuro"
Cognitive = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:cognitive"
snake_robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:snake_robots"
medical_robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_robotics"
locomotion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:locomotion"
biologically_inspired_robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biologically_inspired_robots"
Locomotion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:locomotion"
Biomimetics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomimetics"
bioinspired_robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioinspired_robots"
millirobots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:millirobots"
gecko_inspired_adhesion = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:gecko_inspired_adhesion"
Optimal_Control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:optimal_control"
Motor_Control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:motor_control"
Physical_Simulation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:physical_simulation"
Nonlinear_systems_and_control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nonlinear_systems_and_control"
nonlinear_dynamics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:nonlinear_dynamics"
biomedical_and_energy_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomedical_and_energy_systems"
bioengineering = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bioengineering"
UAVs = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:uavs"
Multi_Agent_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:multi_agent_systems"
biorobotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biorobotics"
motor_control = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:motor_control"
biofilm = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biofilm"
microbiology = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:microbiology"
oral_diseases = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:oral_diseases"
Medical_robotics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:medical_robotics"
robot_ethics = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:robot_ethics"
autonomous_agents = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:autonomous_agents"
neuroscience = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:neuroscience"
Secure_Systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:secure_systems"
Embedded_Software = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:embedded_software"
Reinforcement_learning = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:reinforcement_learning"
automotive_systems = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:automotive_systems"
bipedal_robots = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:bipedal_robots"
Biomechanical_Simulation = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:biomechanical_simulation"

# %%
# put url here
# or choos one from above
TARGET_LABEL_URL = "https://scholar.google.com/citations?view_op=search_authors&hl=ko&mauthors=label:machine_learning"

START_IDX = 0

# set how many pages you want to crawl
WIDTH = 100

author_name_list = []

driver = webdriver.Chrome()
driver.get(TARGET_LABEL_URL)
# button tag is of type "button" and class value is "gs_btnPR gs_in_ib gs_btn_half gs_btn_lsb gs_btn_srt gsc_pgn_pnx"
#utton = driver.find_element(by=By.XPATH, value='//*[@class="gsc_pgn_pnx"]')
#button.click()

for i in range(START_IDX, START_IDX + WIDTH) :
    soup = BeautifulSoup(driver.page_source, "html.parser")
    author_html_list = soup.find_all("h3", class_ = "gs_ai_name")
    for author_html in author_html_list :
        author_name_list.append(author_html.text)

    button_list = driver.find_elements(by=By.XPATH, value='//button')
    button_list[-1].click()
    driver.implicitly_wait(10)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[16], line 17
#      12 # button tag is of type "button" and class value is "gs_btnPR gs_in_ib gs_btn_half gs_btn_lsb gs_btn_srt gsc_pgn_pnx"
#      13 #utton = driver.find_element(by=By.XPATH, value='//*[@class="gsc_pgn_pnx"]')
#      14 #button.click()
#      16 for i in range(START_IDX, START_IDX + WIDTH) :
# ---> 17     soup = BeautifulSoup(driver.page_source, "html.parser")
#      18     author_html_list = soup.find_all("h3", class_ = "gs_ai_name")
#      19     for author_html in author_html_list :
#
# File /opt/anaconda3/envs/rdb/lib/python3.10/site-packages/selenium/webdriver/remote/webdriver.py:449, in WebDriver.page_source(self)
#     440 @property
#     441 def page_source(self) -> str:
#     442     """Gets the source of the current page.
#     443
#     444     :Usage:
#    (...)
# ...

# %%
# save to author name list
with open("./author_name_list.json", "w") as f :
    json.dump(author_name_list, f, indent=4)
